# %% [markdown]
# # Estrategia news and twitter sentiment
#
# ## Autor: Lucía Saiz Lapique
#
# __Examen__
#
# __Gestión de Activos y Carteras__
#
# __CUNEF__

# %% [markdown]
# Esta estrategia de optimización de carteras, o modelo de predicción de rendimientos a estudiar es la estrategia de análisis de sentimiendo de noticias. De todos los datos proporcionados, esta estrategia utiliza únicamente los datos de sentimiento de las noticias (los de Twitter no eran suficientes) de cada activo, donde los valores rondan entre -1 y 1 (-1 siendo la peor nota y 1 la mejor).
#
# Como explicamos en la preparación previa de los datos, los activos seleccionados son 59 activos pertenecientes a 4 índices distintos: Ibex 35, Euro Stoxx, Nasdaq y Dow Jones. Esta estrategia realiza un ranking de todos los activos en función a las posiciones de cada uno a corto o largo plazo (la importancia de cada plazo depende del peso que le demos a cada una y será explicada más adelante). El objetivo no es solo optimizar las rentabilidades de las acciones seleccionadas, sino hacer pruebas a la hora de seleccionar una estrategia u otra.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# Importamos los datos estudiados anteriormente.

# %%
datos = pd.read_excel('datos_examen2.xlsx', sheet_name = 'Datos')
datos = datos.set_index('Name')
datos
# Out:
#                                       Symbol    Price Currency  \
# Name
# L'OREAL                         OR FP Equity  269.700      EUR
# VINCI SA                        DG FP Equity   90.320      EUR
# BANCO BILBAO VIZCAYA ARGENTA  BBVA SQ Equity    3.527      EUR
# BANCO SANTANDER SA             SAN SQ Equity    2.527      EUR
# ASML HOLDING NV               ASML NA Equity  320.500      EUR
# ...                                      ...      ...      ...
# CISCO SYSTEMS INC             CSCO UW Equity   47.830      USD
# EXXON MOBIL CORP               XOM UN Equity   53.080      USD
# WALGREENS BOOTS ALLIANCE INC   WBA UW Equity   45.350      USD
# PFIZER INC                     PFE UN Equity   35.990      USD
# DOW INC                        DOW UN Equity   43.970      USD
#
#                                                 Sector        Country  \
# Name
# L'OREAL                        Cosmetics/Personal Care         FRANCE
# VINCI SA                      Engineering&Construction         FRANCE
# BANCO BILBAO VIZCAYA ARGENTA                     Banks          SPAIN
# BANCO SANTANDER SA                               Banks          SPAIN
# ASML HOLDING NV                         Semiconductors    NETHERLANDS
# ...                                                ...            ...
# CISCO SYSTEMS INC                   Telecommunications  UNITED STATES
# EXXON MOBIL CORP                               Oil&Gas  UNITED STATES
# WALGREENS BOOTS ALLIANCE INC                    Retail  UNITED STATES
# PFIZER INC                             Pharmaceuticals  UNITED STATES
# DOW INC                                      Chemicals  UNITED STATES
#
#                               OPER_MARGIN  RETURN_ON_INV_CAPITAL  \
# Name
# L'OREAL                         17.745099              11.919607
# VINCI SA                        11.180850               7.025344
# BANCO BILBAO VIZCAYA ARGENTA    29.234690               2.635223
# BANCO SANTANDER SA              23.411659               2.868100
# ASML HOLDING NV                 23.610829              17.030943
# ...                                   ...                    ...
# CISCO SYSTEMS INC               27.394806              18.245801
# EXXON MOBIL CORP                 4.511646               2.064358
# WALGREENS BOOTS ALLIANCE INC     3.531922              12.450000
# PFIZER INC                      41.082126              16.668097
# DOW INC                         -1.774115                    NaN
#
#                               ROC_WACC_RATIO  OPERATING_ROIC  \
# Name
# L'OREAL                             1.772554       17.325215
# VINCI SA                            1.417503       10.390774
# BANCO BILBAO VIZCAYA ARGENTA        2.318590        2.221896
# BANCO SANTANDER SA                  2.262225        1.843059
# ASML HOLDING NV                     1.282539       18.505194
# ...                                      ...             ...
# CISCO SYSTEMS INC                   2.558312       24.375592
# EXXON MOBIL CORP                    0.208075        3.210000
# WALGREENS BOOTS ALLIANCE INC        5.120000        6.200000
# PFIZER INC                          3.066011       18.060028
# DOW INC                            -0.760107             NaN
#
#                               OPER_INC_TO_TOT_DEBT  ...  PX_TO_BOOK_RATIO  \
# Name                                                ...
# L'OREAL                                   1.836388  ...           5.11651
# VINCI SA                                  0.168256  ...           2.45154
# BANCO BILBAO VIZCAYA ARGENTA                   NaN  ...          0.478253
# BANCO SANTANDER SA                             NaN  ...          0.435722
# ASML HOLDING NV                           0.841185  ...            10.892
# ...                                            ...  ...               ...
# CISCO SYSTEMS INC                         0.576462  ...           5.65259
# EXXON MOBIL CORP                          0.219104  ...           1.23255
# WALGREENS BOOTS ALLIANCE INC              0.287123  ...           1.68329
# PFIZER INC                                0.397576  ...           3.07367
# DOW INC                                  -0.039779  ...           2.52363
#
#                              PX_TO_CASH_FLOW    EPS_GROWTH DVD_PAYOUT_RATIO  \
# Name
# L'OREAL                              24.2592     -4.267845        63.253283
# VINCI SA                             6.70978      9.293680        51.901082
# BANCO BILBAO VIZCAYA ARGENTA             NaN    -35.080363        49.270218
# BANCO SANTANDER SA                       NaN    -17.593246        58.667174
# ASML HOLDING NV                      42.7511      0.983607        38.866863
# ...                                      ...           ...              ...
# CISCO SYSTEMS INC                    13.0481  13050.000000        51.449961
# EXXON MOBIL CORP                     8.19717    -31.147541       103.514644
# WALGREENS BOOTS ALLIANCE INC         5.91757    -14.792899        41.145831
# PFIZER INC                           14.2324     53.684211        49.979961
# DOW INC                              5.62519           NaN              NaN
#
#                               EQY_REC_CONS  TOT_ANALYST_REC  TOT_BUY_REC  \
# Name
# L'OREAL                           2.967742               31            7
# VINCI SA                          3.760000               25           14
# BANCO BILBAO VIZCAYA ARGENTA      3.093750               32           11
# BANCO SANTANDER SA                3.562500               32           15
# ASML HOLDING NV                   3.951220               41           24
# ...                                    ...              ...          ...
# CISCO SYSTEMS INC                 3.800000               30           14
# EXXON MOBIL CORP                  2.785714               28            3
# WALGREENS BOOTS ALLIANCE INC      2.909091               22            1
# PFIZER INC                        3.823529               17            7
# DOW INC                           3.538461               26            8
#
#                               TOT_SELL_REC  TWITTER_SENTIMENT  NEWS_SENTIMENT
# Name
# L'OREAL                                  8          -0.175997        0.441251
# VINCI SA                                 4          -0.151347       -0.070688
# BANCO BILBAO VIZCAYA ARGENTA             9           0.021949       -0.471481
# BANCO SANTANDER SA                       5           0.004102       -0.468159
# ASML HOLDING NV                          4           0.311931        0.311327
# ...                                    ...                ...             ...
# CISCO SYSTEMS INC                        2          -0.447240        0.311720
# EXXON MOBIL CORP                         6          -0.103257        0.082322
# WALGREENS BOOTS ALLIANCE INC             2          -0.118059       -0.257975
# PFIZER INC                               0           0.094314        0.408576
# DOW INC                                  1           0.011800        0.257114
#
# [217 rows x 22 columns]

# %%
datos.columns
# Out:
# Index(['Symbol', 'Price', 'Currency', 'Sector', 'Country', 'OPER_MARGIN',
#        'RETURN_ON_INV_CAPITAL', 'ROC_WACC_RATIO', 'OPERATING_ROIC',
#        'OPER_INC_TO_TOT_DEBT', 'CUR_MKT_CAP', 'PE_RATIO', 'PX_TO_BOOK_RATIO',
#        'PX_TO_CASH_FLOW', 'EPS_GROWTH', 'DVD_PAYOUT_RATIO', 'EQY_REC_CONS',
#        'TOT_ANALYST_REC', 'TOT_BUY_REC', 'TOT_SELL_REC', 'TWITTER_SENTIMENT',
#        'NEWS_SENTIMENT'],
#       dtype='object')

# %% [markdown]
# Importamos también, por separado, los datos históricos de cada activo.

# %%
historicos = pd.read_excel('datos_examen2.xlsx', sheet_name = 'Precios acciones')
historicos['Date'] = pd.to_datetime(historicos['Date'], format="%Y-%m-%d")
historicos = historicos.set_index('Date')
observacion = historicos.index >= dt.datetime(2015, 4, 30)
historicos = historicos[(observacion)]
historicos.head()
# Out:
#             L'OREAL  VINCI SA  BANCO BILBAO VIZCAYA ARGENTA  \
# Date
# 2015-04-30   170.45     54.82                         9.000
# 2015-05-01   170.45     54.82                         9.000
# 2015-05-04   173.35     54.60                         9.040
# 2015-05-05   166.70     53.76                         8.825
# 2015-05-06   167.75     53.30                         8.949
#
#             BANCO SANTANDER SA  ASML HOLDING NV  KONINKLIJKE PHILIPS NV  \
# Date
# 2015-04-30              6.6449            96.71                  25.655
# 2015-05-01              6.6449            96.71                  25.655
# 2015-05-04              6.6380            96.78                  25.440
# 2015-05-05              6.4128            94.75                  25.190
# 2015-05-06              6.4816            93.67                  25.080
#
#             TELEFONICA SA  TOTAL SA  AIR LIQUIDE SA  AXA SA  ...  \
# Date                                                         ...
# 2015-04-30         13.640    48.485         94.0205  22.615  ...
# 2015-05-01         13.640    48.485         94.0205  22.615  ...
# 2015-05-04         13.765    48.130         95.4695  22.735  ...
# 2015-05-05         13.515    47.675         93.4168  22.275  ...
# 2015-05-06         13.520    47.845         93.9803  22.540  ...
#
#             MERCK & CO. INC.  INTEL CORP.1  RAYTHEON TECHNOLOGIES CORP  \
# Date
# 2015-04-30             59.56         32.55                      67.091
# 2015-05-01             59.86         33.42                      68.088
# 2015-05-04             60.64         33.43                      68.684
# 2015-05-05             60.49         32.64                      67.870
# 2015-05-06             60.26         32.22                      67.876
#
#             VERIZON COMMUNICATIONS INC  COCA-COLA CO/THE  CISCO SYSTEMS INC.1  \
# Date
# 2015-04-30                       50.44             40.56                28.83
# 2015-05-01                       50.41             40.91                29.13
# 2015-05-04                       50.52             40.96                29.17
# 2015-05-05                       50.09             40.75                28.89
# 2015-05-06                       49.64             40.66                28.97
#
#             EXXON MOBIL CORP  WALGREENS BOOTS ALLIANCE INC.1  PFIZER INC  \
# Date
# 2015-04-30             87.37                           82.93       33.93
# 2015-05-01             88.85                           83.46       34.08
# 2015-05-04             89.11                           84.13       34.32
# 2015-05-05             88.61                           83.14       34.12
# 2015-05-06             88.19                           83.10       33.46
#
#             DOW INC
# Date
# 2015-04-30      NaN
# 2015-05-01      NaN
# 2015-05-04      NaN
# 2015-05-05      NaN
# 2015-05-06      NaN
#
# [5 rows x 218 columns]

# %%
historicos.columns
# Out:
# Index(['L'OREAL', 'VINCI SA', 'BANCO BILBAO VIZCAYA ARGENTA',
#        'BANCO SANTANDER SA', 'ASML HOLDING NV', 'KONINKLIJKE PHILIPS NV',
#        'TELEFONICA SA', 'TOTAL SA', 'AIR LIQUIDE SA', 'AXA SA',
#        ...
#        'MERCK & CO. INC.', 'INTEL CORP.1', 'RAYTHEON TECHNOLOGIES CORP',
#        'VERIZON COMMUNICATIONS INC', 'COCA-COLA CO/THE', 'CISCO SYSTEMS INC.1',
#        'EXXON MOBIL CORP', 'WALGREENS BOOTS ALLIANCE INC.1', 'PFIZER INC',
#        'DOW INC'],
#       dtype='object', length=218)

# %%
indice = pd.read_excel('datos_examen2.xlsx', sheet_name = 'Precios Index')
indice['Date'] = pd.to_datetime(indice['Date'], format="%Y-%m-%d")
indice = indice.set_index('Date')
observacion = indice.index >= dt.datetime(2015, 4, 30)
indice = indice[(observacion)]
indice.head()
# Out:
#             Euro Stoxx 50 Pr  IBEX 35 INDEX  DOW JONES INDUS. AVG  MSCI WORLD  \
# Date
# 2015-04-30           3615.59        11385.0              17840.52     1778.40
# 2015-05-01           3615.59        11385.0              18024.06     1787.40
# 2015-05-04           3632.94        11429.1              18070.40     1790.83
# 2015-05-05           3546.56        11115.6              17928.20     1773.42
# 2015-05-06           3558.03        11163.6              17841.98     1772.82
#
#             NASDAQ COMPOSITE INDEX  S&P 500 INDEX  NIKKEI 225  FTSE 100 INDEX
# Date
# 2015-04-30                4941.424        2085.51    19520.01         6960.63
# 2015-05-01                5005.391        2108.29    19531.63         6985.95
# 2015-05-04                5016.929        2114.49    19531.63         6985.95
# 2015-05-05                4939.327        2089.46    19531.63         6927.58
# 2015-05-06                4919.645        2080.15    19531.63         6933.74

# %% [markdown]
# Seleccionamos únicamente la variable de sentimientos de noticias de todos los datos proporcionados para crear el ranking y los pesos ya que, en esta estrategia, son los únicos que se deben aplicar. Para ello, creamos un nuevo dataframe que será utilizado de ahora en adelante como los datos originales.

# %%
cuenta = datos.Symbol.count()
sentim = datos[['NEWS_SENTIMENT', 'TWITTER_SENTIMENT']]
sentim.index = datos.index
sentim.head()
# Out:
#                               NEWS_SENTIMENT  TWITTER_SENTIMENT
# Name
# L'OREAL                             0.441251          -0.175997
# VINCI SA                           -0.070688          -0.151347
# BANCO BILBAO VIZCAYA ARGENTA       -0.471481           0.021949
# BANCO SANTANDER SA                 -0.468159           0.004102
# ASML HOLDING NV                     0.311327           0.311931

# %%
ranking = sentim.rank(ascending=True) 
ranking.head()
# Out:
#                               NEWS_SENTIMENT  TWITTER_SENTIMENT
# Name
# L'OREAL                                207.0               68.0
# VINCI SA                               104.0               71.0
# BANCO BILBAO VIZCAYA ARGENTA             5.0              111.0
# BANCO SANTANDER SA                       6.0              105.0
# ASML HOLDING NV                        178.0              180.0

# %% [markdown]
# ## Estrategia: mismo peso en corto que en largo
#
# Al igual que en la estrategia de recomendaciones, seleccionamos unos pesos para el largo y corto plazo y se lo aplicamos a cada variable en función del ranking anterior. En este caso, se selecciona aplicarle __el mismo peso al corto plazo que al largo__ pues aporta más rentabilidad (se ha seleccionado por prueba y error, estudiando los resultados finales de la estrategia) y es más estable que de forma opuesta, poniendole más peso al largo. Decidimos, además, apalancar esta estrategia (aplicando pesos de 200%) para obtener mejores resultados, pues de hacer lo contrario, con el tiempo, esta estrategia no sería tan óptima.
#
# Una vez seleccionada nuestra estrategia, decidimos aplicarle una importancia de 50 y 50 a cada plazo (corto y largo respectivamente) para que tengan el mismo peso.

# %%
corto = 50.0
largo = 50.0
peso_corto = -2
peso_largo = 2

# %% [markdown]
# A continuación, generamos un dataframe con los pesos finales de cada activo, teniendo en cuenta si tienen un mejor ranking en corto o en el largo plazo.

# %%
lista = []
for i in ranking['NEWS_SENTIMENT']:
    m = []
    if i <= largo: 
        pesos = peso_largo/largo
        m.append(pesos)
    elif i >= (cuenta + 1 - corto): 
        pesos = peso_corto/corto
        m.append(pesos)
    else:
        pesos = 0
        m.append(pesos)
    lista.extend(m)
    weights = pd.DataFrame(lista, columns = ['NEWS_SENTIMENT'])

# %%
lista2 = []
for i in ranking['TWITTER_SENTIMENT']:
    m = []
    if i <= largo: 
        pesos = peso_largo/largo
        m.append(pesos)
    elif i >= (cuenta + 1 - corto): 
        pesos = peso_corto/corto
        m.append(pesos)
    else:
        pesos = 0
        m.append(pesos)
    lista2.extend(m)
    weights2 = pd.DataFrame(lista2, columns = ['TWITTER_SENTIMENT'])

# %% [markdown]
# Juntando los pesos de cada variable, obtenemos los pesos finales y añadimos una columna con el peso total de cada activo en base a su horizonte temporal. En el horizonte temporal hemos elegido poner más pesos a las rentabilidades en corto (1 mes y 3 meses) y muy poca a las rentabilidades en largo.

# %%
weights['TWITTER_SENTIMENT'] = weights2['TWITTER_SENTIMENT']
weights['Symbol'] = datos.index
weights = weights.set_index('Symbol')
weights.head()
# Out:
#                               NEWS_SENTIMENT  TWITTER_SENTIMENT
# Symbol
# L'OREAL                                -0.04               0.00
# VINCI SA                                0.00               0.00
# BANCO BILBAO VIZCAYA ARGENTA            0.04               0.00
# BANCO SANTANDER SA                      0.04               0.00
# ASML HOLDING NV                        -0.04              -0.04

# %%
imp = [0.45, 0.55]
sum(imp)
# Out:
# 1.0

# %%
weights['Total'] = (imp*weights).sum(axis=1)
weights.head()
# Out:
#                               NEWS_SENTIMENT  TWITTER_SENTIMENT  Total
# Symbol
# L'OREAL                                -0.04               0.00 -0.018
# VINCI SA                                0.00               0.00  0.000
# BANCO BILBAO VIZCAYA ARGENTA            0.04               0.00  0.018
# BANCO SANTANDER SA                      0.04               0.00  0.018
# ASML HOLDING NV                        -0.04              -0.04 -0.040

# %%
resultados_peliminares = (weights * sentim).sum()
pd.DataFrame(resultados_peliminares, columns = ['Resultados Preliminares']).T
# Out:
#                          NEWS_SENTIMENT  TWITTER_SENTIMENT  Total
# Resultados Preliminares       -1.512678          -1.562189    0.0

# %% [markdown]
# ## Datos finales de la estrategia
#
# Para la parte final de este estudio, debemos tener en cuenta los datos históricos de cada activo importados al principio del análisis. Estimamos el cambio de porcentaje de cada activo para obtener las renntabilidades diarias de cada una y así obtener los datos finales con los que generaremos la cartera óptima.

# %%
historicos.dropna(inplace = True, axis = 1)
df = historicos.pct_change().dropna()
df.head()
# Out:
#              L'OREAL  VINCI SA  BANCO BILBAO VIZCAYA ARGENTA  \
# Date
# 2015-05-01  0.000000  0.000000                      0.000000
# 2015-05-04  0.017014 -0.004013                      0.004444
# 2015-05-05 -0.038362 -0.015385                     -0.023783
# 2015-05-06  0.006299 -0.008557                      0.014051
# 2015-05-07  0.005067 -0.010319                      0.005699
#
#             BANCO SANTANDER SA  ASML HOLDING NV  KONINKLIJKE PHILIPS NV  \
# Date
# 2015-05-01            0.000000         0.000000                0.000000
# 2015-05-04           -0.001038         0.000724               -0.008380
# 2015-05-05           -0.033926        -0.020975               -0.009827
# 2015-05-06            0.010729        -0.011398               -0.004367
# 2015-05-07            0.002129         0.002028               -0.010167
#
#             TELEFONICA SA  TOTAL SA  AIR LIQUIDE SA    AXA SA  ...  \
# Date                                                           ...
# 2015-05-01       0.000000  0.000000        0.000000  0.000000  ...
# 2015-05-04       0.009164 -0.007322        0.015412  0.005306  ...
# 2015-05-05      -0.018162 -0.009454       -0.021501 -0.020233  ...
# 2015-05-06       0.000370  0.003566        0.006032  0.011897  ...
# 2015-05-07      -0.003698 -0.022573       -0.003855  0.028394  ...
#
#             AMERICAN EXPRESS CO  MERCK & CO. INC.  INTEL CORP.1  \
# Date
# 2015-05-01             0.002970          0.005037      0.026728
# 2015-05-04             0.007724          0.013030      0.000299
# 2015-05-05            -0.005621         -0.002474     -0.023631
# 2015-05-06             0.000128         -0.003802     -0.012868
# 2015-05-07             0.007450          0.000664      0.000776
#
#             RAYTHEON TECHNOLOGIES CORP  VERIZON COMMUNICATIONS INC  \
# Date
# 2015-05-01                    0.014860                   -0.000595
# 2015-05-04                    0.008753                    0.002182
# 2015-05-05                   -0.011851                   -0.008511
# 2015-05-06                    0.000088                   -0.008984
# 2015-05-07                    0.008339                    0.001813
#
#             COCA-COLA CO/THE  CISCO SYSTEMS INC.1  EXXON MOBIL CORP  \
# Date
# 2015-05-01          0.008629             0.010406          0.016939
# 2015-05-04          0.001222             0.001373          0.002926
# 2015-05-05         -0.005127            -0.009599         -0.005611
# 2015-05-06         -0.002209             0.002769         -0.004740
# 2015-05-07          0.000984            -0.005696         -0.006690
#
#             WALGREENS BOOTS ALLIANCE INC.1  PFIZER INC
# Date
# 2015-05-01                        0.006391    0.004421
# 2015-05-04                        0.008028    0.007042
# 2015-05-05                       -0.011768   -0.005828
# 2015-05-06                       -0.000481   -0.019343
# 2015-05-07                        0.013598    0.003586
#
# [5 rows x 204 columns]

# %%
def ratios(sentim, weights):
    '''
        returns = dataframe que contiene las rentabilidades diarias de los activos
        weights = pesos de los activos para cada uno de los periodos de tiempo y en total
        -----------------------------------------------------------------------------------
        final = resultado de la estrategia
    '''
    
    # genero los resultados como un indice de base 100
    resultados = [100]
    
    # cojo los pesos totales de la matriz de pesos
    pesos = weights.iloc[:,-1]
    
    # voy calculado los resultados como el anterior mas 1 por la rentabilidad que se obtienen diariamente de las
    # distintas acciones y sus pesos
    for i in range(1, len(sentim)):
        
        value = resultados[i-1] * (1 + (sentim.iloc[i] * pesos).sum())
        
        resultados.append(value)
    
    # meto en un dataframe para devovler el resultado final y asigno las fechas coo indice
    final = pd.DataFrame(resultados, columns=['Sentiment'])  
    final.set_index(sentim.index, inplace=True)
        
    return final

# %% [markdown]
# En el dataframe a continuación, podemos observar el resultado de esta estrategia y la graficamos a continuación. Como podemos observar, el resultado ha aumentado considerablemente en 5 años, aunque en menor proporción que la estrategia de recomendaciones.

# %%
final = ratios(df, weights)
final
# Out:
#              Sentiment
# Date
# 2015-05-01  100.000000
# 2015-05-04  100.295759
# 2015-05-05   99.612971
# 2015-05-06   99.657093
# 2015-05-07   99.455399
# ...                ...
# 2020-06-01  122.659358
# 2020-06-02  122.838346
# 2020-06-03  122.771270
# 2020-06-04  122.906261
# 2020-06-05  123.913288
#
# [1331 rows x 1 columns]

# %% [markdown]
# Podemos concluir que la selección de pesos para los datos en cuestión es correcta (al aplicar el mayor peso al largo que al corto plazo o viceversa, los resultados eran peores y la subida era mucho menos estable, es decir, que había más volatilidad).

# %%
plt.figure(figsize=(20,10))
plt.plot(final.index, final['Sentiment'], marker='', markerfacecolor='blue', markersize=12, color='skyblue', 
         linewidth=4, label ='Sentiment')
plt.plot(indice["MSCI WORLD"], marker='', markerfacecolor='violet', markersize=12, color='violet', 
         linewidth=4, label ='Índice MSCI')
plt.legend(prop={"size":15}, loc="upper left")

# %%
final.to_csv('Estrategia_Sentiment_final.csv')
