# %% [markdown]
# # Estrategia news sentiment
# ## Autor: María Carrasco Meléndez, Raquel Fort Serra y Lucía Saiz Lapique
#
# __Práctica 4__
#
# __Gestión de Activos y Carteras__
#
# __CUNEF__

# %% [markdown]
# Esta estrategia de optimización de carteras, o modelo de predicción de rendimientos a estudiar es la estrategia de análisis de sentimiendo de noticias. De todos los datos proporcionados, esta estrategia utiliza únicamente los datos de sentimiento de las noticias (los de Twitter no eran suficientes) de cada activo, donde los valores rondan entre -1 y 1 (-1 siendo la peor nota y 1 la mejor).
#
# Como explicamos en la preparación previa de los datos, los activos seleccionados son 59 activos pertenecientes a 4 índices distintos: Ibex 35, Euro Stoxx, Nasdaq y Dow Jones. Esta estrategia realiza un ranking de todos los activos en función a las posiciones de cada uno a corto o largo plazo (la importancia de cada plazo depende del peso que le demos a cada una y será explicada más adelante). El objetivo no es solo optimizar las rentabilidades de las acciones seleccionadas, sino hacer pruebas a la hora de seleccionar una estrategia u otra.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importamos los datos estudiados anteriormente.

# %%
datos = pd.read_csv('activos_finales.csv')
datos = datos.set_index('Symbol')
datos.head()
# Out:
#                           Name    Price Currency                   Sector  \
# Symbol
# FRE     FRESENIUS SE & CO KGAA   43.880      EUR      Healthcare-Services
# PHIA    KONINKLIJKE PHILIPS NV   42.040      EUR      Healthcare-Products
# ORA                     ORANGE   10.395      EUR       Telecommunications
# OR                     L'OREAL  251.100      EUR  Cosmetics/Personal Care
# ASML           ASML HOLDING NV  295.600      EUR           Semiconductors
#
#             Country  Rentab 1M  Rentab 3M  Rentab 1Y  Rentab 2Y  Rentab 3Y  \
# Symbol
# FRE         GERMANY   0.165162  -0.063294  -0.076405  -0.341636  -0.116814
# PHIA    NETHERLANDS   0.057610   0.030771   0.163898   0.002897   0.114594
# ORA          FRANCE  -0.070630  -0.197607  -0.254839   0.025109   0.047468
# OR           FRANCE   0.032059  -0.006332   0.032484   0.108156   0.085859
# ASML    NETHERLANDS   0.108361   0.109818   0.734742  -0.046739   0.374452
#
#         ...    PX_TO_BOOK_RATIO     PX_TO_CASH_FLOW          EPS_GROWTH  \
# Symbol  ...
# FRE     ...  1.4237820242958328   5.038176807835165  -7.397260273972603
# PHIA    ...   2.973449150377937  18.847019540996918  -7.205460569050113
# ORA     ...  1.0626812500467617    2.71270613202884  63.492063492063494
# OR      ...   4.763649494786657  22.586171168445816   -4.26784482758621
# ASML    ...  10.045748564335948   39.42971046957317  0.9836065573770574
#
#           DVD_PAYOUT_RATIO EQY_REC_CONS TOT_ANALYST_REC TOT_BUY_REC  \
# Symbol
# FRE     24.864534379182157     4.538462              26          20
# PHIA     63.85562575885329     4.115385              26          16
# ORA      67.75820093864134     4.258065              31          21
# OR      63.253283233333335     3.032258              31           7
# ASML    38.866863187131116     3.925000              40          23
#
#        TOT_SELL_REC TWITTER_SENTIMENT_REALTIME     NEWS_SENTIMENT_RT
# Symbol
# FRE               0                        0.0                 0.663
# PHIA              1                        0.0                     0
# ORA               1                        0.0                 0.234
# OR                7                        0.0                     0
# ASML              4                        0.0  -0.10678147706595072
#
# [5 rows x 25 columns]

# %%
datos.head()
# Out:
#                           Name    Price Currency                   Sector  \
# Symbol
# FRE     FRESENIUS SE & CO KGAA   43.880      EUR      Healthcare-Services
# PHIA    KONINKLIJKE PHILIPS NV   42.040      EUR      Healthcare-Products
# ORA                     ORANGE   10.395      EUR       Telecommunications
# OR                     L'OREAL  251.100      EUR  Cosmetics/Personal Care
# ASML           ASML HOLDING NV  295.600      EUR           Semiconductors
#
#             Country  Rentab 1M  Rentab 3M  Rentab 1Y  Rentab 2Y  Rentab 3Y  \
# Symbol
# FRE         GERMANY   0.165162  -0.063294  -0.076405  -0.341636  -0.116814
# PHIA    NETHERLANDS   0.057610   0.030771   0.163898   0.002897   0.114594
# ORA          FRANCE  -0.070630  -0.197607  -0.254839   0.025109   0.047468
# OR           FRANCE   0.032059  -0.006332   0.032484   0.108156   0.085859
# ASML    NETHERLANDS   0.108361   0.109818   0.734742  -0.046739   0.374452
#
#         ...    PX_TO_BOOK_RATIO     PX_TO_CASH_FLOW          EPS_GROWTH  \
# Symbol  ...
# FRE     ...  1.4237820242958328   5.038176807835165  -7.397260273972603
# PHIA    ...   2.973449150377937  18.847019540996918  -7.205460569050113
# ORA     ...  1.0626812500467617    2.71270613202884  63.492063492063494
# OR      ...   4.763649494786657  22.586171168445816   -4.26784482758621
# ASML    ...  10.045748564335948   39.42971046957317  0.9836065573770574
#
#           DVD_PAYOUT_RATIO EQY_REC_CONS TOT_ANALYST_REC TOT_BUY_REC  \
# Symbol
# FRE     24.864534379182157     4.538462              26          20
# PHIA     63.85562575885329     4.115385              26          16
# ORA      67.75820093864134     4.258065              31          21
# OR      63.253283233333335     3.032258              31           7
# ASML    38.866863187131116     3.925000              40          23
#
#        TOT_SELL_REC TWITTER_SENTIMENT_REALTIME     NEWS_SENTIMENT_RT
# Symbol
# FRE               0                        0.0                 0.663
# PHIA              1                        0.0                     0
# ORA               1                        0.0                 0.234
# OR                7                        0.0                     0
# ASML              4                        0.0  -0.10678147706595072
#
# [5 rows x 25 columns]

# %%
historicos = pd.read_csv('datos_historicos.csv')
historicos = historicos.set_index('Date')
historicos.pop('SAN.1')
historicos.pop('SAN.2')
historicos.pop('SAN.3')
historicos.head()
# Out:
#                   FRE       PHIA     ORA          OR       ASML    IBE  \
# Date
# 2015-01-02  42.535000  24.174999  14.060  137.399994  89.129997  5.596
# 2015-01-05  42.410000  23.375000  13.520  134.149994  87.489998  5.495
# 2015-01-06  42.840000  23.155001  13.370  134.149994  84.669998  5.473
# 2015-01-07  42.544998  23.275000  13.590  134.899994  84.949997  5.466
# 2015-01-08  43.810001  23.865000  14.205  139.800003  88.190002  5.574
#
#                    SU         BN     DTE        SAN  ...          HD  \
# Date                                                 ...
# 2015-01-02  59.950001  53.860001  13.185  75.440002  ...  103.430000
# 2015-01-05  57.340000  52.480000  12.780  73.269997  ...  101.260002
# 2015-01-06  57.419998  52.320000  12.630  73.510002  ...  100.949997
# 2015-01-07  57.779999  52.930000  12.990  74.290001  ...  104.410004
# 2015-01-08  60.160000  54.459999  13.630  77.419998  ...  106.720001
#
#                     GS       INTC        MRK        JPM          BA  \
# Date
# 2015-01-02  194.410004  36.360001  57.189999  62.490002  129.949997
# 2015-01-05  188.339996  35.950001  58.040001  60.549999  129.050003
# 2015-01-06  184.529999  35.279999  60.320000  58.980000  127.529999
# 2015-01-07  187.279999  36.020000  61.610001  59.070000  129.509995
# 2015-01-08  190.270004  36.689999  62.849998  60.389999  131.800003
#
#                   WBA         VZ        AXP       CSCO
# Date
# 2015-01-02  76.000000  46.959999  93.019997  27.610001
# 2015-01-05  74.500000  46.570000  90.559998  27.059999
# 2015-01-06  74.690002  47.040001  88.629997  27.049999
# 2015-01-07  76.599998  46.189999  90.300003  27.299999
# 2015-01-08  77.550003  47.180000  91.580002  27.510000
#
# [5 rows x 58 columns]

# %% [markdown]
# Seleccionamos únicamente la variable de sentimientos de noticias de todos los datos proporcionados para crear el ranking y los pesos ya que, en esta estrategia, son los únicos que se deben aplicar. Para ello, creamos un nuevo dataframe que será utilizado de ahora en adelante como los datos originales.

# %%
cuenta = datos.Name.count()
sentim = datos[['NEWS_SENTIMENT_RT']]
sentim.index = datos.index
sentim.head()
# Out:
#            NEWS_SENTIMENT_RT
# Symbol
# FRE                    0.663
# PHIA                       0
# ORA                    0.234
# OR                         0
# ASML    -0.10678147706595072

# %%
ranking = sentim.rank(ascending=False) 
ranking.head()
# Out:
#         NEWS_SENTIMENT_RT
# Symbol
# FRE                   4.0
# PHIA                 35.0
# ORA                  18.0
# OR                   35.0
# ASML                 56.0

# %% [markdown]
# ## Estrategia: mismo peso en corto que en largo
#
# Al igual que en la estrategia de recomendaciones, seleccionamos unos pesos para el largo y corto plazo y se lo aplicamos a cada variable en función del ranking anterior. En este caso, se selecciona aplicarle __el mismo peso al corto plazo que al largo__ pues aporta más rentabilidad (se ha seleccionado por prueba y error, estudiando los resultados finales de la estrategia) y es más estable que de forma opuesta, poniendole más peso al largo. Decidimos, además, apalancar esta estrategia (aplicando pesos de 200%) para obtener mejores resultados, pues de hacer lo contrario, con el tiempo, esta estrategia no sería tan óptima.
#
# Una vez seleccionada nuestra estrategia, decidimos aplicarle una importancia de 50 y 50 a cada plazo (corto y largo respectivamente) para que tengan el mismo peso.

# %%
corto = 50.0
largo = 50.0
peso_corto = -2
peso_largo = 2

# %% [markdown]
# A continuación, generamos un dataframe con los pesos finales de cada activo, teniendo en cuenta si tienen un mejor ranking en corto o en el largo plazo.

# %%
lista = []
for i in ranking['NEWS_SENTIMENT_RT']:
    m = []
    if i <= largo: 
        pesos = peso_largo/largo
        m.append(pesos)
    elif i >= (cuenta + 1 - corto): 
        pesos = peso_corto/corto
        m.append(pesos)
    else:
        pesos = 0
        m.append(pesos)
    lista.extend(m)
    weights = pd.DataFrame(lista, columns = ['NEWS_SENTIMENT_RT'])

# %% [markdown]
# Juntando los pesos de cada variable, obtenemos los pesos finales y añadimos una columna con el peso total de cada activo en base a su horizonte temporal. En el horizonte temporal hemos elegido poner más pesos a las rentabilidades en corto (1 mes y 3 meses) y muy poca a las rentabilidades en largo.

# %%
weights['Symbol'] = datos.index
weights = weights.set_index('Symbol')
weights.head()
# Out:
#         NEWS_SENTIMENT_RT
# Symbol
# FRE                  0.04
# PHIA                 0.04
# ORA                  0.04
# OR                   0.04
# ASML                -0.04

# %% [markdown]
# ## Datos finales de la estrategia
#
# Para la parte final de este estudio, debemos tener en cuenta los datos históricos de cada activo importados al principio del análisis. Estimamos el cambio de porcentaje de cada activo para obtener las renntabilidades diarias de cada una y así obtener los datos finales con los que generaremos la cartera óptima.

# %%
df = historicos.pct_change().dropna()
df.head()
# Out:
#                  FRE      PHIA       ORA        OR      ASML       IBE  \
# Date
# 2015-01-05 -0.002939 -0.033092 -0.038407 -0.023654 -0.018400 -0.018049
# 2015-01-06  0.010139 -0.009412 -0.011095  0.000000 -0.032232 -0.004004
# 2015-01-07 -0.006886  0.005182  0.016455  0.005591  0.003307 -0.001279
# 2015-01-08  0.029733  0.025349  0.045254  0.036323  0.038140  0.019758
# 2015-01-09 -0.005821 -0.028284 -0.016543 -0.014306 -0.026647 -0.011661
#
#                   SU        BN       DTE       SAN  ...        HD        GS  \
# Date                                                ...
# 2015-01-05 -0.043536 -0.025622 -0.030717 -0.028765  ... -0.020980 -0.031223
# 2015-01-06  0.001395 -0.003049 -0.011737  0.003276  ... -0.003061 -0.020229
# 2015-01-07  0.006270  0.011659  0.028504  0.010611  ...  0.034274  0.014903
# 2015-01-08  0.041191  0.028906  0.049269  0.042132  ...  0.022124  0.015965
# 2015-01-09 -0.022606 -0.022769 -0.026412 -0.032808  ... -0.017148 -0.015347
#
#                 INTC       MRK       JPM        BA       WBA        VZ  \
# Date
# 2015-01-05 -0.011276  0.014863 -0.031045 -0.006926 -0.019737 -0.008305
# 2015-01-06 -0.018637  0.039283 -0.025929 -0.011778  0.002550  0.010092
# 2015-01-07  0.020975  0.021386  0.001526  0.015526  0.025572 -0.018070
# 2015-01-08  0.018601  0.020127  0.022346  0.017682  0.012402  0.021433
# 2015-01-09  0.001908 -0.004614 -0.017387 -0.001973 -0.024242 -0.008902
#
#                  AXP      CSCO
# Date
# 2015-01-05 -0.026446 -0.019920
# 2015-01-06 -0.021312 -0.000370
# 2015-01-07  0.018842  0.009242
# 2015-01-08  0.014175  0.007692
# 2015-01-09 -0.012667  0.010178
#
# [5 rows x 58 columns]

# %%
def ratios(sentim, weights):
    '''
        returns = dataframe que contiene las rentabilidades diarias de los activos
        weights = pesos de los activos para cada uno de los periodos de tiempo y en total
        -----------------------------------------------------------------------------------
        final = resultado de la estrategia
    '''
    
    # genero los resultados como un indice de base 100
    resultados = [100]
    
    # cojo los pesos totales de la matriz de pesos
    pesos = weights.iloc[:,-1]
    
    # voy calculado los resultados como el anterior mas 1 por la rentabilidad que se obtienen diariamente de las
    # distintas acciones y sus pesos
    for i in range(1, len(sentim)):
        
        value = resultados[i-1] * (1 + (sentim.iloc[i] * pesos).sum())
        
        resultados.append(value)
    
    # meto en un dataframe para devovler el resultado final y asigno las fechas coo indice
    final = pd.DataFrame(resultados, columns=['Sentiment'])  
    final.set_index(sentim.index, inplace=True)
        
    return final

# %% [markdown]
# En el dataframe a continuación, podemos observar el resultado de esta estrategia y la graficamos a continuación. Como podemos observar, el resultado ha aumentado considerablemente en 5 años, aunque en menor proporción que la estrategia de recomendaciones.

# %%
final = ratios(df, weights)
final
# Out:
#              Sentiment
# Date
# 2015-01-05  100.000000
# 2015-01-06   99.568923
# 2015-01-07  100.806070
# 2015-01-08  105.667802
# 2015-01-09  103.451629
# ...                ...
# 2019-12-25  182.014249
# 2019-12-26  182.407505
# 2019-12-27  183.267170
# 2019-12-30  180.505366
# 2019-12-31  180.283638
#
# [1291 rows x 1 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(final.index, final['Sentiment'], marker='', markerfacecolor='blue', markersize=12, color='skyblue', 
         linewidth=4, label ='Sentiment')

# %% [markdown]
# Podemos concluir que la selección de pesos para los datos en cuestión es correcta (al aplicar el mayor peso al largo que al corto plazo o viceversa, los resultados eran peores y la subida era mucho menos estable, es decir, que había más volatilidad).

# %%
final.to_csv('Estrategia_Sentiment_final.csv')
